# %%
print("Hello Airbnb!")
# Out:
# Hello Airbnb!

# %%
from pathlib import Path
import os

# Data files already live decompressed in ../data, no need to resolve a project root
DATA_DIR = Path("../data")

print("Data dir:", DATA_DIR)
# Out:
# Data dir: ../data

# %%
import pandas as pd
calendar = pd.read_csv(
    DATA_DIR / "calendar.csv"
)

calendar
# Out:
#                    listing_id        date available  price  adjusted_price  \
# 0                        2737  2025-09-15         t    NaN             NaN
# 1                        2737  2025-09-16         t    NaN             NaN
# 2                        2737  2025-09-17         t    NaN             NaN
# 3                        2737  2025-09-18         t    NaN             NaN
# 4                        2737  2025-09-19         t    NaN             NaN
# ...                       ...         ...       ...    ...             ...
# 13742978  1505831694220884181  2026-09-10         t    NaN             NaN
# 13742979  1505831694220884181  2026-09-11         t    NaN             NaN
# 13742980  1505831694220884181  2026-09-12         t    NaN             NaN
# 13742981  1505831694220884181  2026-09-13         t    NaN             NaN
# 13742982  1505831694220884181  2026-09-14         t    NaN             NaN
#
#           minimum_nights  maximum_nights
# 0                     31            1125
# 1                     31            1125
# 2                     31            1125
# 3                     31            1125
# 4                     31            1125
# ...                  ...             ...
# 13742978               2              30
# 13742979               2              30
# 13742980               2              30
# 13742981               2              30
# 13742982               2              30
#
# [13742983 rows x 7 columns]

# %%
calendar.columns.tolist()
# Out:
# ['listing_id',
#  'date',
#  'available',
#  'price',
#  'adjusted_price',
#  'minimum_nights',
#  'maximum_nights']

# %%
with open(DATA_DIR / "calendar.csv", "rt") as f:
    for _ in range(5):
        print(f.readline())
# Out:
# listing_id,date,available,price,adjusted_price,minimum_nights,maximum_nights
#
# 2737,2025-09-15,t,,,31,1125
#
# 2737,2025-09-16,t,,,31,1125
#
# 2737,2025-09-17,t,,,31,1125
#
# 2737,2025-09-18,t,,,31,1125

# %%
calendar.sample
# Out:
# <bound method NDFrame.sample of                    listing_id        date available  price  adjusted_price  \
# 0                        2737  2025-09-15         t    NaN             NaN
# 1                        2737  2025-09-16         t    NaN             NaN
# 2                        2737  2025-09-17         t    NaN             NaN
# 3                        2737  2025-09-18         t    NaN             NaN
# 4                        2737  2025-09-19         t    NaN             NaN
# ...                       ...         ...       ...    ...             ...
# 13742978  1505831694220884181  2026-09-10         t    NaN             NaN
# 13742979  1505831694220884181  2026-09-11         t    NaN             NaN
# 13742980  1505831694220884181  2026-09-12         t    NaN             NaN
# 13742981  1505831694220884181  2026-09-13         t    NaN             NaN
# 13742982  1505831694220884181  2026-09-14         t    NaN             NaN
#
#           minimum_nights  maximum_nights
# 0                     31            1125
# 1                     31            1125
# 2                     31            1125
# 3                     31            1125
# 4                     31            1125
# ...                  ...             ...
# 13742978               2              30
# 13742979               2              30
# 13742980               2              30
# 13742981               2              30
# 13742982               2              30
#
# [13742983 rows x 7 columns]>

# %%
calendar.shape
# Out:
# (13742983, 7)

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13742983 entries, 0 to 13742982
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           float64
#  4   adjusted_price  float64
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 734.0+ MB

# %%
calendar.isna().sum()
# Out:
# listing_id               0
# date                     0
# available                0
# price             13742983
# adjusted_price    13742983
# minimum_nights           0
# maximum_nights           0
# dtype: int64

# %%
calendar["listing_id"].unique().tolist()
# Out:
# [2737,
#  11834,
#  1149356,
#  473219,
#  1153507,
#  473825,
#  12398,
#  1156028,
#  475751,
#  19965,
#  1157936,
#  482695,
#  1165064,
#  19967,
#  1165204,
#  484000,
#  484371,
#  1168778,
#  20534,
#  490737,
#  1170571,
#  493461,
#  1172635,
#  20587,
#  495127,
#  1173808,
#  498478,
#  20699,
#  1176688,
#  1188745,
#  21193,
#  500154,
#  1188916,
#  500959,
#  1189026,
#  501912,
#  1190188,
#  21811,
#  504814,
#  1190619,
#  504821,
#  1193247,
#  22573,
#  1202234,
#  510665,
#  512967,
#  1213068,
#  22930,
#  1219644,
#  527124,
#  527250,
#  25875,
#  1221610,
#  1222414,
#  527539,
#  29606,
#  1222808,
#  531710,
#  1224305,
#  37054,
#  1224367,
#  37305,
#  1231282,
#  37307,
#  532061,
#  532077,
#  1234346,
#  43912,
#  1234389,
#  535946,
#  47213,
#  1236381,
#  48807,
#  1241663,
#  536190,
#  1242019,
#  49240,
#  1245631,
#  50333,
#  1247378,
#  50471,
#  1247379,
#  539322,
#  1248307,
#  53203,
#  539492,
#  1248421,
#  53265,
#  1248462,
#  541240,
#  1248601,
#  541589,
#  53322,
#  1250526,
#  1255470,
#  542118,
#  53325,
#  1255945,
#  1259613,
#  542420,
#  1262834,
#  544843,
#  54991,
#  546203,
#  1265506,
#  1269648,
#  55710,
#  1269785,
#  550400,
#  553026,
#  1269786,
#  553816,
#  56795,
#  558620,
#  1272359,
#  1273143,
#  56801,
#  1274703,
#  560450,
#  561231,
#  1275095,
#  57982,
#  1279489,
#  561736,
#  562080,
#  58273,
#  566437,
#  1279847,
#  567563,
#  1284276,
#  59749,
#  570448,
#  1286346,
#  573109,
#  1290984,
#  60300,
#  576496,
#  1295484,
#  577461,
#  1298999,
#  63092,
#  1308906,
#  581723,
#  584129,
#  1314863,
#  64683,
#  1315692,
#  588080,
#  588527,
#  65104,
#  590418,
#  1318455,
#  1325114,
#  592150,
#  70477,
#  592165,
#  1325688,
#  597568,
#  70621,
#  1325870,
#  1326389,
#  601402,
#  1329535,
#  603234,
#  71341,
#  1331465,
#  603558,
#  73235,
#  603639,
#  1333040,
#  1333060,
#  608586,
#  1336228,
#  75474,
#  1338292,
#  610411,
#  77831,
#  612843,
#  1338414,
#  1338805,
#  614621,
#  618500,
#  1344535,
#  80280,
#  618566,
#  1345398,
#  619022,
#  80292,
#  1346899,
#  80612,
#  1350044,
#  619724,
#  624562,
#  1355670,
#  624916,
#  84226,
#  1356223,
#  627933,
#  629441,
#  1357193,
#  84953,
#  1357322,
#  636895,
#  1358895,
#  639627,
#  85857,
#  642001,
#  1359051,
#  86187,
#  1359379,
#  645705,
#  1361769,
#  647163,
#  1362127,
#  88428,
#  647884,
#  1362672,
#  650151,
#  1362719,
#  90666,
#  653570,
#  1363642,
#  90902,
#  653881,
#  1366218,
#  90971,
#  654241,
#  1366699,
#  91029,
#  1367990,
#  657412,
#  662235,
#  1371698,
#  91713,
#  1373696,
#  667421,
#  1375848,
#  667806,
#  93976,
#  1379166,
#  672101,
#  94106,
#  674274,
#  1379683,
#  679808,
#  1380573,
#  679886,
#  1383520,
#  683861,
#  95415,
#  1384971,
#  1385250,
#  96351,
#  1385476,
#  686007,
#  96755,
#  1395729,
#  690097,
#  1396390,
#  99620,
#  691189,
#  1405707,
#  1409935,
#  691271,
#  691453,
#  691626,
#  1410746,
#  1426138,
#  1429549,
#  692218,
#  99635,
#  1429891,
#  692245,
#  102672,
#  1437103,
#  692885,
#  103190,
#  693077,
#  1439331,
#  103245,
#  1441028,
#  103870,
#  1442379,
#  693110,
#  108035,
#  1444489,
#  693148,
#  1457239,
#  108039,
#  693641,
#  695228,
#  1457339,
#  1460331,
#  1470028,
#  1478063,
#  696277,
#  113590,
#  1478654,
#  116291,
#  1480512,
#  696777,
#  1482320,
#  117251,
#  1482573,
#  697070,
#  1493344,
#  118803,
#  1498555,
#  697853,
#  698322,
#  124269,
#  1505964,
#  698925,
#  125484,
#  700932,
#  1506512,
#  1510306,
#  131221,
#  1512093,
#  704162,
#  705322,
#  135307,
#  706782,
#  1513413,
#  709855,
#  137713,
#  711563,
#  1516877,
#  137724,
#  711649,
#  138192,
#  712160,
#  712185,
#  139330,
#  1517622,
#  140801,
#  721874,
#  141614,
#  723163,
#  723197,
#  141634,
#  723544,
#  1527233,
#  142483,
#  724038,
#  147381,
#  724050,
#  1527384,
#  1537866,
#  728961,
#  1542173,
#  147670,
#  1555602,
#  730032,
#  1558235,
#  730793,
#  731825,
#  1569644,
#  153542,
#  732058,
#  1569923,
#  732890,
#  1572766,
#  735417,
#  1577160,
#  737165,
#  155179,
#  738826,
#  1583398,
#  1585548,
#  739341,
#  1591237,
#  1591494,
#  156445,
#  1603038,
#  742809,
#  743172,
#  744222,
#  1605462,
#  744651,
#  1616260,
#  156873,
#  1622577,
#  750042,
#  750055,
#  1628927,
#  750472,
#  1631785,
#  158722,
#  1639457,
#  750579,
#  756083,
#  1642397,
#  758234,
#  158761,
#  758338,
#  1649869,
#  1659145,
#  758874,
#  1659241,
#  759644,
#  1660134,
#  161978,
#  766376,
#  1663034,
#  1666559,
#  766424,
#  1675940,
#  769178,
#  1678049,
#  163008,
#  1680544,
#  770099,
#  771124,
#  771363,
#  1680601,
#  1684889,
#  163107,
#  1685119,
#  773473,
#  773478,
#  1685835,
#  1685977,
#  773978,
#  163111,
#  775658,
#  1686289,
#  166454,
#  1686299,
#  778012,
#  166894,
#  1689820,
#  780791,
#  171442,
#  781445,
#  1690544,
#  172334,
#  1694320,
#  782198,
#  175380,
#  782316,
#  1695277,
#  1698263,
#  783263,
#  181189,
#  1698381,
#  783986,
#  181747,
#  784311,
#  1701223,
#  1711129,
#  784486,
#  182862,
#  790785,
#  1712162,
#  183969,
#  792474,
#  1719412,
#  794009,
#  186484,
#  1720861,
#  794880,
#  1721243,
#  1722762,
#  795513,
#  1722794,
#  795973,
#  191877,
#  1724948,
#  797400,
#  192711,
#  1726378,
#  797406,
#  192859,
#  798038,
#  1727003,
#  1727047,
#  799892,
#  1728482,
#  194786,
#  800145,
#  801311,
#  1731683,
#  195032,
#  801891,
#  1737656,
#  802413,
#  1737805,
#  196714,
#  806822,
#  210511,
#  808450,
#  1738926,
#  1742087,
#  809178,
#  220921,
#  811973,
#  1745265,
#  1746946,
#  812342,
#  221063,
#  812387,
#  1749720,
#  1750382,
#  1752936,
#  814208,
#  223154,
#  816682,
#  818616,
#  818839,
#  1753266,
#  1755014,
#  1757047,
#  226372,
#  1760382,
#  1760943,
#  1767483,
#  1771104,
#  820686,
#  820984,
#  825299,
#  825367,
#  1772830,
#  228872,
#  1773055,
#  1774792,
#  1777173,
#  827269,
#  834023,
#  836133,
#  838023,
#  1780721,
#  1781054,
#  1782572,
#  841633,
#  843160,
#  228911,
#  843518,
#  1788527,
#  843660,
#  1794163,
#  1794758,
#  844558,
#  230295,
#  844662,
#  844776,
#  844967,
#  1794852,
#  1795349,
#  1795753,
#  847691,
#  1799281,
#  1802304,
#  848506,
#  850183,
#  850630,
#  1807733,
#  1810132,
#  852680,
#  230555,
#  852799,
#  855707,
#  855912,
#  1812997,
#  1816578,
#  1817663,
#  857405,
#  231116,
#  857445,
#  1820891,
#  1821487,
#  859685,
#  861697,
#  861908,
#  1822289,
#  1825004,
#  231654,
#  1829956,
#  866666,
#  866871,
#  1833428,
#  232470,
#  1834527,
#  870683,
#  1836484,
#  870905,
#  234534,
#  871542,
#  1837102,
#  1837156,
#  872825,
#  234538,
#  1837490,
#  875320,
#  234540,
#  876289,
#  1839104,
#  1842308,
#  877012,
#  877647,
#  234542,
#  878385,
#  1845427,
#  1846106,
#  1850506,
#  878946,
#  880092,
#  1852546,
#  882945,
#  234544,
#  886953,
#  1858199,
#  1859296,
#  888645,
#  1859522,
#  1861215,
#  890346,
#  1869326,
#  896524,
#  1871589,
#  235858,
#  1873235,
#  897047,
#  897360,
#  1883835,
#  899297,
#  239234,
#  900368,
#  1884342,
#  1899664,
#  901668,
#  239253,
#  906915,
#  909242,
#  239288,
#  1899903,
#  909292,
#  1903889,
#  239293,
#  914466,
#  240706,
#  915670,
#  243353,
#  917861,
#  920132,
#  1904558,
#  922888,
#  1906111,
#  245450,
#  1906698,
#  925502,
#  928448,
#  928606,
#  1907616,
#  247254,
#  1913068,
#  1915512,
#  248552,
#  1915870,
#  930540,
#  1918551,
#  249258,
#  1921378,
#  930655,
#  931146,
#  932380,
#  255221,
#  1927120,
#  935007,
#  255532,
#  935188,
#  1927584,
#  935231,
#  256695,
#  935763,
#  1938051,
#  937861,
#  1938361,
#  258330,
#  1938770,
#  943348,
#  944491,
#  1940941,
#  1942255,
#  944620,
#  946643,
#  1942531,
#  947193,
#  1948352,
#  1953292,
#  951498,
#  953372,
#  1954356,
#  1963599,
#  259075,
#  1967945,
#  1973270,
#  954590,
#  954760,
#  956475,
#  1977079,
#  956558,
#  262254,
#  957703,
#  958119,
#  958253,
#  1987761,
#  1989322,
#  1991186,
#  959198,
#  262313,
#  963119,
#  1991241,
#  963429,
#  965158,
#  262876,
#  965942,
#  1992391,
#  263658,
#  1994079,
#  965980,
#  967027,
#  1996506,
#  968004,
#  264679,
#  969018,
#  1996805,
#  969606,
#  969865,
#  266296,
#  971894,
#  269143,
#  1997075,
#  971905,
#  271812,
#  976389,
#  272634,
#  982623,
#  273092,
#  983127,
#  2004556,
#  983997,
#  273971,
#  984119,
#  2005365,
#  275420,
#  984327,
#  984549,
#  276602,
#  984559,
#  984729,
#  277084,
#  988524,
#  280117,
#  988700,
#  280198,
#  990139,
#  991917,
#  2005424,
#  281393,
#  993609,
#  2005557,
#  281629,
#  994966,
#  995129,
#  2005657,
#  282037,
#  995829,
#  2009275,
#  995864,
#  282831,
#  2013581,
#  998048,
#  282929,
#  2014061,
#  998427,
#  283620,
#  1000039,
#  2014374,
#  2015008,
#  1002079,
#  283699,
#  2015913,
#  1002897,
#  1003046,
#  2021994,
#  285564,
#  2032354,
#  1003392,
#  287297,
#  1004844,
#  2032532,
#  2040244,
#  1006879,
#  2040598,
#  1007981,
#  289471,
#  2044150,
#  2044585,
#  290388,
#  1008155,
#  2045155,
#  1008848,
#  291274,
#  2045309,
#  1013370,
#  293274,
#  2048737,
#  1014376,
#  2050603,
#  295715,
#  1015224,
#  2052808,
#  295755,
#  1015669,
#  1015838,
#  2052858,
#  297562,
#  1018266,
#  2052914,
#  297635,
#  2053893,
#  1019643,
#  2054130,
#  1034024,
#  297933,
#  2059443,
#  1036406,
#  298031,
#  1040846,
#  2060459,
#  2063590,
#  1041693,
#  2066633,
#  2066682,
#  1042725,
#  299695,
#  1045646,
#  2066720,
#  300848,
#  1047490,
#  1047661,
#  302154,
#  1049639,
#  2070324,
#  1049640,
#  302157,
#  1049890,
#  1050056,
#  305009,
#  1051382,
#  2070912,
#  1054322,
#  305081,
#  1054445,
#  307429,
#  1054864,
#  2071346,
#  307892,
#  1057911,
#  1058785,
#  309086,
#  1058802,
#  1059026,
#  310005,
#  1061245,
#  315264,
#  1067728,
#  2077017,
#  1072962,
#  317380,
#  1078734,
#  1082840,
#  1082841,
#  320025,
#  1084634,
#  1084807,
#  322226,
#  1085980,
#  1086785,
#  2080532,
#  1093514,
#  1093536,
#  322298,
#  1098701,
#  2081501,
#  322712,
#  2085571,
#  1099890,
#  1106021,
#  2087982,
#  323283,
#  1106585,
#  2090019,
#  1108531,
#  2096246,
#  1113395,
#  325175,
#  1114127,
#  2104609,
#  2106558,
#  325252,
#  1114163,
#  2112872,
#  1114549,
#  2113046,
#  325961,
#  1114679,
#  2113077,
#  326062,
#  2113668,
#  1115423,
#  326361,
#  1116417,
#  1123660,
#  2113739,
#  2114752,
#  2121721,
#  1125570,
#  326494,
#  2122587,
#  1126422,
#  326537,
#  2125934,
#  1127071,
#  2131315,
#  329492,
#  2134276,
#  1136511,
#  1136842,
#  2137890,
#  329494,
#  2144496,
#  1137487,
#  1140116,
#  329551,
#  2149094,
#  1147091,
#  2150629,
#  329646,
#  2152593,
#  1147741,
#  2153298,
#  2248694,
#  329669,
#  2154899,
#  2253422,
#  2157401,
#  330798,
#  2157476,
#  2255434,
#  2259850,
#  2163410,
#  2265424,
#  332616,
#  2265519,
#  2164809,
#  2174112,
#  2269904,
#  2271281,
#  2174421,
#  332998,
#  2174425,
#  2272032,
#  2278108,
#  2184669,
#  334323,
#  2187108,
#  2280866,
#  2191664,
#  335009,
#  2288739,
#  2192963,
#  2289472,
#  2193487,
#  336413,
#  2290363,
#  2194996,
#  2299901,
#  2195366,
#  2300468,
#  2201384,
#  2310315,
#  2201485,
#  339319,
#  2311857,
#  2208668,
#  2318010,
#  339692,
#  2319281,
#  2212712,
#  2224701,
#  2319535,
#  2225558,
#  340097,
#  2229649,
#  340173,
#  2230708,
#  2323982,
#  341703,
#  ...]

# %% [markdown]
# ## Check unique values in availability

# %%
calendar["available"].value_counts()
# Out:
# available
# t    8152085
# f    5590898
# Name: count, dtype: int64

# %% [markdown]
# ## Check datatypes

# %%
calendar.dtypes
# Out:
# listing_id          int64
# date               object
# available          object
# price             float64
# adjusted_price    float64
# minimum_nights      int64
# maximum_nights      int64
# dtype: object

# %%
listings = pd.read_csv(
    DATA_DIR / "listings.csv",
    nrows=5
)

listings[["id", "price"]]
# Out:
#       id    price
# 0   2737   $57.00
# 1  11834  $110.00
# 2  12398  $124.00
# 3  19965  $162.00
# 4  19967  $150.00

# %%
listings["price"].head()
# Out:
# 0     $57.00
# 1    $110.00
# 2    $124.00
# 3    $162.00
# 4    $150.00
# Name: price, dtype: object

# %%
listings["price"].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Data Source Selection
#
# The calendar dataset was initially considered as the source of the target variable. However, `calendar.csv` does not include `price` or `adjusted_price` columns at all — it only contains `listing_id`, `date`, `available`, `minimum_nights`, and `maximum_nights`.
#
# Therefore, the listings dataset was selected as the source of the target variable (`price`), since it contains valid nightly price information for all listings.
