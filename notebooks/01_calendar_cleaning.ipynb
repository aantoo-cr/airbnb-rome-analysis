# %%
print("Hello Airbnb!")
# Out:
# Hello Airbnb!

# %%
from pathlib import Path
import os

# Data files already live decompressed in ../data, no need to resolve a project root
DATA_DIR = Path("../data")

print("Data dir:", DATA_DIR)
# Out:
# Data dir: ../data

# %%
import pandas as pd
calendar = pd.read_csv(
    DATA_DIR / "calendar.csv"
)

calendar
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 calendar = pd.read_csv(
#       3     DATA_DIR / "calendar.csv"
#       4 )
#       5
#
# File ~/Data for business/airbnb-rome-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/Data for business/airbnb-rome-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/Data for business/airbnb-rome-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/Data for business/airbnb-rome-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File ~/Data for business/airbnb-rome-analysis/.venv/lib/python3.13/site-packages/pandas/io/parsers/c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      92 if kwds["dtype_backend"] == "pyarrow":
#      93     # Fail here loudly instead of in cython after reading
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#      99 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:568, in pandas._libs.parsers.TextReader.__cinit__()
# --> 568 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:657, in pandas._libs.parsers.TextReader._get_header()
# --> 657 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:868, in pandas._libs.parsers.TextReader._tokenize_rows()
# --> 868 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:885, in pandas._libs.parsers.TextReader._check_tokenize_status()
# --> 885 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:2076, in pandas._libs.parsers.raise_parser_error()
# -> 2076 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen codecs>:325, in BufferedIncrementalDecoder.decode(self, input, final)
#     322 'Could not get source, probably due dynamically evaluated source code.'
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte

# %%
calendar.columns.tolist()
# Out:
# ['listing_id', 'date', 'available', 'minimum_nights', 'maximum_nights']

# %%
with open(DATA_DIR / "calendar.csv", "rt") as f:
    for _ in range(5):
        print(f.readline())
# Out:
# listing_id,date,available,minimum_nights,maximum_nights
#
# 93976,2026-06-22,f,4,1125
#
# 93976,2026-06-23,f,4,1125
#
# 93976,2026-06-24,f,4,1125
#
# 93976,2026-06-25,f,4,1125

# %%
calendar.sample
# Out:
# <bound method NDFrame.sample of                    listing_id        date available  minimum_nights  \
# 0                       93976  2026-06-22         f               4
# 1                       93976  2026-06-23         f               4
# 2                       93976  2026-06-24         f               4
# 3                       93976  2026-06-25         f               4
# 4                       93976  2026-06-26         f               4
# ...                       ...         ...       ...             ...
# 13588238  1711795600320259607  2027-06-16         f               1
# 13588239  1711795600320259607  2027-06-17         f               1
# 13588240  1711795600320259607  2027-06-18         f               1
# 13588241  1711795600320259607  2027-06-19         f               1
# 13588242  1711795600320259607  2027-06-20         f               1
#
#           maximum_nights
# 0                   1125
# 1                   1125
# 2                   1125
# 3                   1125
# 4                   1125
# ...                  ...
# 13588238              15
# 13588239              15
# 13588240              15
# 13588241              15
# 13588242              15
#
# [13588243 rows x 5 columns]>

# %%
calendar.shape
# Out:
# (13588243, 5)

# %%
calendar.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13588243 entries, 0 to 13588242
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            str
#  2   available       str
#  3   minimum_nights  int64
#  4   maximum_nights  int64
# dtypes: int64(3), str(2)
# memory usage: 518.4 MB

# %%
calendar.isna().sum()
# Out:
# listing_id        0
# date              0
# available         0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
calendar["listing_id"].unique().tolist()
# Out:
# [93976,
#  2737,
#  11834,
#  12398,
#  19965,
#  20534,
#  20587,
#  20699,
#  21193,
#  21811,
#  22573,
#  22930,
#  25875,
#  29606,
#  37305,
#  37307,
#  43912,
#  48807,
#  49240,
#  50333,
#  50471,
#  53203,
#  53265,
#  53322,
#  53325,
#  54991,
#  55710,
#  56795,
#  56801,
#  57982,
#  58273,
#  59749,
#  60300,
#  63092,
#  64683,
#  65104,
#  70477,
#  70621,
#  71341,
#  73235,
#  75474,
#  77831,
#  80280,
#  80292,
#  80612,
#  84226,
#  84953,
#  85857,
#  86187,
#  88428,
#  90666,
#  90902,
#  90971,
#  91029,
#  94106,
#  95415,
#  96351,
#  96755,
#  99620,
#  99635,
#  102672,
#  103245,
#  103870,
#  108035,
#  108039,
#  113590,
#  116291,
#  117251,
#  118803,
#  124269,
#  125484,
#  131221,
#  135307,
#  137713,
#  137724,
#  138192,
#  139330,
#  140801,
#  141614,
#  141634,
#  142483,
#  147381,
#  147670,
#  153542,
#  155179,
#  156445,
#  156873,
#  158722,
#  158761,
#  163008,
#  166454,
#  166894,
#  171442,
#  172334,
#  175380,
#  181189,
#  181747,
#  182862,
#  183969,
#  186484,
#  191877,
#  192711,
#  192859,
#  194786,
#  195032,
#  196714,
#  210511,
#  220921,
#  223154,
#  226372,
#  228872,
#  228911,
#  230295,
#  230555,
#  231116,
#  231654,
#  232470,
#  234534,
#  234538,
#  234540,
#  234542,
#  234544,
#  235858,
#  239234,
#  239253,
#  239288,
#  239293,
#  240706,
#  242420,
#  243353,
#  245450,
#  247254,
#  255221,
#  255532,
#  256695,
#  258330,
#  259075,
#  262254,
#  262313,
#  262876,
#  263658,
#  264679,
#  266296,
#  269143,
#  271812,
#  272634,
#  273092,
#  273971,
#  275213,
#  275420,
#  276602,
#  277084,
#  280117,
#  280198,
#  281393,
#  281629,
#  282037,
#  282831,
#  282929,
#  283620,
#  283699,
#  285564,
#  287297,
#  289471,
#  290388,
#  291274,
#  293274,
#  295715,
#  295755,
#  297562,
#  297635,
#  297933,
#  298031,
#  299695,
#  300848,
#  302154,
#  302157,
#  305009,
#  305081,
#  307429,
#  307892,
#  309086,
#  315264,
#  317380,
#  320025,
#  322226,
#  322298,
#  323283,
#  325175,
#  325252,
#  325961,
#  326062,
#  326361,
#  326494,
#  326537,
#  329412,
#  329492,
#  329494,
#  329551,
#  329646,
#  329669,
#  330798,
#  332616,
#  332998,
#  334323,
#  335009,
#  336413,
#  339319,
#  339692,
#  340097,
#  340173,
#  341703,
#  342058,
#  343883,
#  354159,
#  356046,
#  363364,
#  366441,
#  370630,
#  370699,
#  377095,
#  383422,
#  384369,
#  386625,
#  387704,
#  392407,
#  394822,
#  395813,
#  396074,
#  396836,
#  396870,
#  396871,
#  399381,
#  400826,
#  402510,
#  407422,
#  408154,
#  409020,
#  409028,
#  409226,
#  409578,
#  409920,
#  410941,
#  411259,
#  414211,
#  414444,
#  415254,
#  415705,
#  417824,
#  419871,
#  421145,
#  422410,
#  424531,
#  426237,
#  426720,
#  427190,
#  427481,
#  427944,
#  428414,
#  432720,
#  434341,
#  434512,
#  436480,
#  439098,
#  440255,
#  443404,
#  444469,
#  445298,
#  448362,
#  451971,
#  452216,
#  452376,
#  456199,
#  457241,
#  457302,
#  458170,
#  463691,
#  464953,
#  467064,
#  468300,
#  469145,
#  471821,
#  472700,
#  473219,
#  473825,
#  475751,
#  482695,
#  484000,
#  484371,
#  490737,
#  493461,
#  495127,
#  498478,
#  500154,
#  501912,
#  504814,
#  504821,
#  508294,
#  510665,
#  512967,
#  527124,
#  527250,
#  527539,
#  531710,
#  532061,
#  532077,
#  535946,
#  536190,
#  539322,
#  539492,
#  541240,
#  542118,
#  542420,
#  544843,
#  546203,
#  550400,
#  553026,
#  553816,
#  558620,
#  560450,
#  561231,
#  562080,
#  567563,
#  570448,
#  573109,
#  576496,
#  577461,
#  581723,
#  588080,
#  588527,
#  590418,
#  592150,
#  592165,
#  601402,
#  603234,
#  603558,
#  603639,
#  608586,
#  610411,
#  612843,
#  614621,
#  618500,
#  618566,
#  619022,
#  624562,
#  627933,
#  629441,
#  636895,
#  639627,
#  642001,
#  645705,
#  647163,
#  647884,
#  650151,
#  653570,
#  653881,
#  654241,
#  657412,
#  662235,
#  667421,
#  667806,
#  672101,
#  674274,
#  679808,
#  679886,
#  683861,
#  686007,
#  690097,
#  691189,
#  691271,
#  691453,
#  691626,
#  692218,
#  692245,
#  692885,
#  693077,
#  693148,
#  693641,
#  695228,
#  696277,
#  696777,
#  697070,
#  697853,
#  698322,
#  698925,
#  700932,
#  704162,
#  705322,
#  706782,
#  709855,
#  711563,
#  711649,
#  712160,
#  712185,
#  721874,
#  723163,
#  723197,
#  723544,
#  724038,
#  724050,
#  728961,
#  730032,
#  730793,
#  731825,
#  732058,
#  732890,
#  735417,
#  737165,
#  738826,
#  739341,
#  744651,
#  750042,
#  750055,
#  750472,
#  756083,
#  758338,
#  758874,
#  759644,
#  766376,
#  766424,
#  769178,
#  770099,
#  771124,
#  771363,
#  773473,
#  773478,
#  773978,
#  775658,
#  778012,
#  780791,
#  781445,
#  782198,
#  782316,
#  783263,
#  783986,
#  784311,
#  784486,
#  790785,
#  792474,
#  794009,
#  794880,
#  795513,
#  797400,
#  797406,
#  800145,
#  801311,
#  801891,
#  802413,
#  806822,
#  808450,
#  809178,
#  811973,
#  812342,
#  812387,
#  816682,
#  818616,
#  818839,
#  820686,
#  820984,
#  825299,
#  825367,
#  827269,
#  834023,
#  836133,
#  838023,
#  841633,
#  843160,
#  843518,
#  843660,
#  844558,
#  844662,
#  844776,
#  844967,
#  847691,
#  848506,
#  850183,
#  850630,
#  852680,
#  852799,
#  855707,
#  855912,
#  857405,
#  857445,
#  859685,
#  861697,
#  866666,
#  866871,
#  870683,
#  870905,
#  871542,
#  872825,
#  876289,
#  877012,
#  877647,
#  878385,
#  880092,
#  882945,
#  886953,
#  888645,
#  896524,
#  897047,
#  897360,
#  899297,
#  900368,
#  901668,
#  906915,
#  909292,
#  914466,
#  917861,
#  918176,
#  919454,
#  920132,
#  921386,
#  922888,
#  925502,
#  928448,
#  928606,
#  930540,
#  930655,
#  931146,
#  932380,
#  935007,
#  935188,
#  935231,
#  936100,
#  937861,
#  943348,
#  944491,
#  944620,
#  946643,
#  947193,
#  951498,
#  953372,
#  954590,
#  954760,
#  956475,
#  956558,
#  957703,
#  958119,
#  958253,
#  959198,
#  963119,
#  963429,
#  965158,
#  965942,
#  965980,
#  968004,
#  969018,
#  969606,
#  969865,
#  971894,
#  971905,
#  974699,
#  976389,
#  982623,
#  983127,
#  983997,
#  984119,
#  984327,
#  984549,
#  984559,
#  984729,
#  988524,
#  988700,
#  990139,
#  991917,
#  993609,
#  994966,
#  995129,
#  995829,
#  995864,
#  998048,
#  998427,
#  1000039,
#  1002079,
#  1002897,
#  1003046,
#  1003392,
#  1004844,
#  1006879,
#  1008155,
#  1008848,
#  1009094,
#  1013370,
#  1014376,
#  1015224,
#  1018446,
#  1019643,
#  1024236,
#  1026336,
#  1034024,
#  1040846,
#  1041693,
#  1042725,
#  1045646,
#  1045674,
#  1047490,
#  1047661,
#  1049639,
#  1049640,
#  1049890,
#  1050056,
#  1051382,
#  1054445,
#  1054864,
#  1057911,
#  1058802,
#  1059026,
#  1061245,
#  1067728,
#  1069884,
#  1072962,
#  1078734,
#  1082840,
#  1082841,
#  1084634,
#  1084807,
#  1085980,
#  1086785,
#  1093514,
#  1093536,
#  1098701,
#  1099890,
#  1106021,
#  1106585,
#  1108531,
#  1113395,
#  1114127,
#  1114163,
#  1114549,
#  1114679,
#  1115423,
#  1116417,
#  1123660,
#  1125570,
#  1126422,
#  1127071,
#  1136511,
#  1136842,
#  1137487,
#  1140116,
#  1147091,
#  1147741,
#  1149356,
#  1153507,
#  1156028,
#  1157936,
#  1165064,
#  1165204,
#  1170571,
#  1172635,
#  1173808,
#  1176688,
#  1189026,
#  1190188,
#  1190619,
#  1193247,
#  1202234,
#  1213068,
#  1221610,
#  1222414,
#  1222808,
#  1224305,
#  1224367,
#  1231282,
#  1234346,
#  1234389,
#  1236381,
#  1241663,
#  1242019,
#  1245631,
#  1247378,
#  1247379,
#  1248307,
#  1248421,
#  1248462,
#  1248601,
#  1250526,
#  1255470,
#  1255945,
#  1259613,
#  1262834,
#  1265506,
#  1269648,
#  1269785,
#  1269786,
#  1272359,
#  1273143,
#  1274703,
#  1275095,
#  1279489,
#  1279847,
#  1284276,
#  1286346,
#  1290984,
#  1295484,
#  1298999,
#  1308906,
#  1314863,
#  1315692,
#  1318455,
#  1325114,
#  1325688,
#  1325870,
#  1329535,
#  1331465,
#  1333040,
#  1333060,
#  1336228,
#  1338292,
#  1338414,
#  1338805,
#  1344535,
#  1345398,
#  1346899,
#  1350044,
#  1355670,
#  1356223,
#  1358895,
#  1359051,
#  1359379,
#  1361769,
#  1362127,
#  1362672,
#  1363642,
#  1366218,
#  1366699,
#  1367990,
#  1371698,
#  1373696,
#  1375848,
#  1379166,
#  1379683,
#  1380573,
#  1383520,
#  1384971,
#  1385250,
#  1385476,
#  1388923,
#  1390002,
#  1395729,
#  1396390,
#  1405707,
#  1409935,
#  1410746,
#  1426138,
#  1429549,
#  1429891,
#  1439331,
#  1441028,
#  1442379,
#  1444489,
#  1457239,
#  1457339,
#  1460331,
#  1470028,
#  1478063,
#  1478654,
#  1480512,
#  1482320,
#  1482573,
#  1487640,
#  1493344,
#  1498555,
#  1505964,
#  1506512,
#  1510306,
#  1512093,
#  1516877,
#  1527233,
#  1527384,
#  1542173,
#  1555602,
#  1558235,
#  1569644,
#  1569923,
#  1572766,
#  1577160,
#  1585548,
#  1591237,
#  1591238,
#  1603038,
#  1605462,
#  1622577,
#  1628927,
#  1631785,
#  1639457,
#  1642397,
#  1649869,
#  1659145,
#  1659241,
#  1660134,
#  1663034,
#  1666559,
#  1678049,
#  1680544,
#  1680601,
#  1684889,
#  1685119,
#  1685835,
#  1685977,
#  1686289,
#  1686299,
#  1689820,
#  1690544,
#  1694320,
#  1695277,
#  1698263,
#  1698381,
#  1701223,
#  1705128,
#  1711129,
#  1712162,
#  1719412,
#  1720861,
#  1722762,
#  1722794,
#  1724948,
#  1726378,
#  1727003,
#  1727047,
#  1728482,
#  1731683,
#  1737656,
#  1737805,
#  1738926,
#  1742087,
#  1745265,
#  1745861,
#  1746946,
#  1749720,
#  1750382,
#  1755014,
#  1760382,
#  1760943,
#  1767483,
#  1771104,
#  1772830,
#  1773055,
#  1777173,
#  1780721,
#  1781054,
#  1782572,
#  1787302,
#  1788527,
#  1794163,
#  1794758,
#  1794852,
#  1795349,
#  1795753,
#  1799281,
#  1810132,
#  1812997,
#  1816578,
#  1817663,
#  1818221,
#  1820891,
#  1821487,
#  1822289,
#  1825004,
#  1829956,
#  1834527,
#  1836484,
#  1837102,
#  1837156,
#  1837490,
#  1842308,
#  1845427,
#  1846106,
#  1850506,
#  1852546,
#  1858199,
#  1859296,
#  1859522,
#  1861215,
#  1869326,
#  1871589,
#  1873235,
#  1877627,
#  1883835,
#  1884342,
#  1899664,
#  1900671,
#  1903889,
#  1904558,
#  1906111,
#  1906698,
#  1907616,
#  1913068,
#  1915512,
#  1915870,
#  1921378,
#  1927584,
#  1938051,
#  1938361,
#  1938770,
#  1940941,
#  1942531,
#  1948352,
#  1953292,
#  1954356,
#  1963599,
#  1967945,
#  1973270,
#  1977079,
#  1981468,
#  1987761,
#  1989322,
#  1991186,
#  1991241,
#  1992391,
#  1994079,
#  1996506,
#  1996805,
#  1997075,
#  2005365,
#  2005424,
#  2005557,
#  2005657,
#  2009275,
#  2013581,
#  2014061,
#  2014374,
#  2015008,
#  2015913,
#  2021994,
#  2032354,
#  2032532,
#  2040244,
#  2040598,
#  2044150,
#  2044585,
#  2045155,
#  2048737,
#  2050603,
#  2052808,
#  2052858,
#  2052914,
#  2053893,
#  2059443,
#  2060459,
#  2063590,
#  2070912,
#  2071346,
#  2077017,
#  2080532,
#  2081501,
#  2085571,
#  2087982,
#  2090019,
#  2096246,
#  2104609,
#  2106558,
#  2113046,
#  2113077,
#  2113668,
#  2113739,
#  2114752,
#  2121721,
#  2125934,
#  2131315,
#  2134276,
#  2137890,
#  2138011,
#  2144078,
#  2144496,
#  2149094,
#  2150629,
#  2152593,
#  2153298,
#  2154899,
#  2157401,
#  2157476,
#  2163410,
#  2164809,
#  2174112,
#  2174421,
#  2174425,
#  2184669,
#  2191664,
#  2192963,
#  2193487,
#  2194996,
#  2195366,
#  2199581,
#  2201384,
#  2208668,
#  2212712,
#  2224701,
#  2225558,
#  2229649,
#  2230708,
#  2237338,
#  2238996,
#  2253422,
#  2255434,
#  2259850,
#  2265424,
#  2265519,
#  2269904,
#  ...]

# %% [markdown]
# ## Check unique values in availability

# %%
calendar["available"].value_counts()
# Out:
# available
# t    7953168
# f    5635075
# Name: count, dtype: int64

# %% [markdown]
# ## Check datatypes

# %%
calendar.dtypes
# Out:
# listing_id        int64
# date                str
# available           str
# minimum_nights    int64
# maximum_nights    int64
# dtype: object

# %%
listings = pd.read_csv(
    DATA_DIR / "listings.csv",
    nrows=5
)

listings[["id", "price"]]
# Out:
#       id    price
# 0   2737   $59.52
# 1  11834      NaN
# 2  12398  $117.13
# 3  19965  $160.60
# 4  20534  $243.67

# %%
listings["price"].head()
# Out:
# 0     $59.52
# 1        NaN
# 2    $117.13
# 3    $160.60
# 4    $243.67
# Name: price, dtype: str

# %%
listings["price"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %% [markdown]
# ## Data Source Selection
#
# The calendar dataset was initially considered as the source of the target variable. However, `calendar.csv` does not include `price` or `adjusted_price` columns at all — it only contains `listing_id`, `date`, `available`, `minimum_nights`, and `maximum_nights`.
#
# Therefore, the listings dataset was selected as the source of the target variable (`price`), since it contains valid nightly price information for all listings.
